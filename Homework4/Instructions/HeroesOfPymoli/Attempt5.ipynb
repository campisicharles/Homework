# %%
# Dependencies and Setup
import pandas as pd
import numpy as np

# File to Load (Remember to Change These)
file_to_load = "Resources/purchase_data.csv"

# Read Purchasing File and store into Pandas data frame
purchase_data = pd.read_csv(file_to_load)

# %%
# Show just the header
#see what i got on a data front
purchase_data.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %%
# If it wasn't for the example, I probably would have used purchase ID, but the numbers didn't match, which made me think that ScreenName would probably be better
# Calculate the total number of players in the DataFrame
playercount = len(purchase_data["SN"].unique())
playercount
# Out:
# 576

# %%
playercount = pd.DataFrame({"Total Players":[playercount]})
playercount
# Out:
#    Total Players
# 0            576

# %%
### Purchasing Analysis (Total)
#Number of Unique Items
UniqueItems = len(purchase_data["Item Name"].unique())
UniqueItems
# Out:
# 179

# %%
#avg purchase price
AvgPrice = purchase_data["Price"].mean()
AvgPrice
# Out:
# 3.050987179487176

# %%
#Total Number of Purchases
NumberPurchases = len(purchase_data["Purchase ID"].unique())
NumberPurchases
# Out:
# 780

# %%
#Total Revenue
TotalRev = purchase_data["Price"].sum()
TotalRev
# Out:
# 2379.77

# %%
# Place all of the data found into a summary DataFrame
summary_table2 = pd.DataFrame({"Number of Unique Items": UniqueItems,
                              "Average Price": [AvgPrice],
                              "Number of Purchases": NumberPurchases,
                              "Total Revenue": [TotalRev]})
summary_table2
# Out:
#    Number of Unique Items  Average Price  Number of Purchases  Total Revenue
# 0                     179       3.050987                  780        2379.77

# %%
summary_table2["Average Price"] = summary_table2["Average Price"].astype(float).map(
    "${:,.2f}".format)
summary_table2["Total Revenue"] = summary_table2["Total Revenue"].astype(float).map(
    "${:,.2f}".format)
summary_table2
# Out:
#    Number of Unique Items Average Price  Number of Purchases Total Revenue
# 0                     179         $3.05                  780     $2,379.77

# %%
PlayerGender = purchase_data["Gender"].value_counts()
PlayerGender
# Out:
# Male                     652
# Female                   113
# Other / Non-Disclosed     15
# Name: Gender, dtype: int64

# %%
# Convert the count Series into a DataFrame - PandaRecap - UGH! - not doing what I hoped it would
playergender_df = pd.DataFrame(PlayerGender)
playergender_df
# Out:
#                        Gender
# Male                      652
# Female                    113
# Other / Non-Disclosed      15

# %%
players_by_gender = purchase_data['Gender'].value_counts()
players_by_gender
# Out:
# Male                     652
# Female                   113
# Other / Non-Disclosed     15
# Name: Gender, dtype: int64

# %%
#Remove Doubles
#not sure how to do this#I had to Google this for days to get these numbers 
GenderCount = purchase_data.groupby("Gender")["SN"].nunique()
GenderCount
# Out:
# Gender
# Female                    81
# Male                     484
# Other / Non-Disclosed     11
# Name: SN, dtype: int64

# %%
GenderCount_df = pd.DataFrame(GenderCount)
GenderCount_df
# Out:
#                         SN
# Gender
# Female                  81
# Male                   484
# Other / Non-Disclosed   11

# %%
GroupedGender = purchase_data.groupby("Gender")
GroupedGender.count()
#Initially had gender in [] and had to Google to try ()
#I need to really hammer the difference between the two into my brain
#####
# Out:
#                        Purchase ID   SN  Age  Item ID  Item Name  Price
# Gender
# Female                         113  113  113      113        113    113
# Male                           652  652  652      652        652    652
# Other / Non-Disclosed           15   15   15       15         15     15

# %%
#Percentage of Players
PlayerGender2 = GenderCount.sum()
PlayerGender2
# Out:
# 576

# %%
MalePer = (GenderCount["Male"] / PlayerGender2)*100
MalePer
# Out:
# 84.02777777777779

# %%
FemalePer = (GenderCount["Female"] / PlayerGender2)*100
FemalePer
# Out:
# 14.0625

# %%
OtherPer = (GenderCount["Other / Non-Disclosed"] / PlayerGender2)*100
OtherPer
# Out:
# 1.9097222222222223

# %%
PlayerPercent = {"FemalePer", "MalePer", "OtherPer"}
PlayerPercent
# Out:
# {'FemalePer', 'MalePer', 'OtherPer'}

# %%
# Place all of the data found into a summary DataFrame
summary_table3 = pd.DataFrame({"Total Count": GenderCount, "Percentage of Players": [FemalePer, MalePer, OtherPer]})
summary_table3
# Out:
#                        Total Count  Percentage of Players
# Gender
# Female                          81              14.062500
# Male                           484              84.027778
# Other / Non-Disclosed           11               1.909722

# %%
### Purchasing Analysis (Gender)
#The below each broken by gender
#Purchase Count
#Average Purchase Price
#Total Purchase Value
#Average Purchase Total per Person by Gender

# %%
#How many people in each Gender made purchase by person
PurchaseCount = GroupedGender["SN"].count()
PurchaseCount
# Out:
# Gender
# Female                   113
# Male                     652
# Other / Non-Disclosed     15
# Name: SN, dtype: int64

# %%
AvgPurPrice = GroupedGender["Price"].mean()
AvgPurPrice
# Out:
# Gender
# Female                   3.203009
# Male                     3.017853
# Other / Non-Disclosed    3.346000
# Name: Price, dtype: float64

# %%
TotalPurPrice = GroupedGender["Price"].sum()
TotalPurPrice
# Out:
# Gender
# Female                    361.94
# Male                     1967.64
# Other / Non-Disclosed      50.19
# Name: Price, dtype: float64

# %%
AvgPerPerson = TotalPurPrice / GenderCount
AvgPerPerson
#This is wrong, but I have to figue out how to do it
#once I got rid of doubles, this works now
# Out:
# Gender
# Female                   4.468395
# Male                     4.065372
# Other / Non-Disclosed    4.562727
# dtype: float64

# %%
summary_table4 = pd.DataFrame({"Purchase Count": PurchaseCount, "Average Purchase Price": AvgPurPrice, "Total Purchase Value": TotalPurPrice, "Avg Total Purchase Per Person": AvgPerPerson})
summary_table4.head()
# Out:
#                        Purchase Count  Average Purchase Price  \
# Gender
# Female                            113                3.203009
# Male                              652                3.017853
# Other / Non-Disclosed              15                3.346000
#
#                        Total Purchase Value  Avg Total Purchase Per Person
# Gender
# Female                               361.94                       4.468395
# Male                                1967.64                       4.065372
# Other / Non-Disclosed                 50.19                       4.562727

# %%
summary_table4["Average Purchase Price"] = summary_table4["Average Purchase Price"].astype(float).map(
    "${:,.2f}".format)
summary_table4["Total Purchase Value"] = summary_table4["Total Purchase Value"].astype(float).map(
    "${:,.2f}".format)
summary_table4["Avg Total Purchase Per Person"] = summary_table4["Avg Total Purchase Per Person"].astype(float).map(
    "${:,.2f}".format)
summary_table4
# Out:
#                        Purchase Count Average Purchase Price  \
# Gender
# Female                            113                  $3.20
# Male                              652                  $3.02
# Other / Non-Disclosed              15                  $3.35
#
#                       Total Purchase Value Avg Total Purchase Per Person
# Gender
# Female                             $361.94                         $4.47
# Male                             $1,967.64                         $4.07
# Other / Non-Disclosed               $50.19                         $4.56

# %%
purchase_data.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %%
### Age Demographics* The below each broken into bins of 4 years (i.e. &lt;10, 10-14, 15-19, etc.)
#Purchase Count
#Average Purchase Price
#Total Purchase Value
#Average Purchase Total per Person by Age Group

# %%
#create the bins
bins = [0, 9, 14, 19, 24, 29, 34, 39, 150]

# Create the names for the four bins
group_names = ("<10", "10-14", "15-19", "20-24", "25-29", "30-34", "35-39", "40+")

# %%
purchase_data["AgeDemographics"] = pd.cut(purchase_data["Age"], bins, labels=group_names)
purchase_data.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price AgeDemographics
# 0  Extraction, Quickblade Of Trembling Hands   3.53           20-24
# 1                          Frenzied Scimitar   1.56             40+
# 2                               Final Critic   4.88           20-24
# 3                                Blindscythe   3.27           20-24
# 4                                       Fury   1.44           20-24

# %%
# Creating a group based off of the bins
Groupbins = purchase_data.groupby("AgeDemographics")
Groupbins
#gotta do a thing to show - per activites
Groupbins.head(15)
# Out:
#      Purchase ID             SN  Age                 Gender  Item ID  \
# 0              0        Lisim78   20                   Male      108
# 1              1    Lisovynya38   40                   Male      143
# 2              2     Ithergue48   24                   Male       92
# 3              3  Chamassasya86   24                   Male      100
# 4              4      Iskosia90   23                   Male      131
# 5              5        Yalae81   22                   Male       81
# 6              6      Itheria73   36                   Male      169
# 7              7    Iskjaskst81   20                   Male      162
# 8              8      Undjask33   22                   Male       21
# 9              9    Chanosian48   35  Other / Non-Disclosed      136
# 10            10      Inguron55   23                   Male       95
# 11            11   Haisrisuir60   23                   Male      162
# 12            12   Saelaephos52   21                   Male      116
# ...

# %%
GroupCount = Groupbins["SN"].count()
GroupCount
# Out:
# AgeDemographics
# <10       23
# 10-14     28
# 15-19    136
# 20-24    365
# 25-29    101
# 30-34     73
# 35-39     41
# 40+       13
# Name: SN, dtype: int64

# %%
# Creating a group based off of the bins
Groupbins = purchase_data.groupby("AgeDemographics")["SN"].nunique()
Groupbins
#gotta do a thing to show - per activites
Groupbins.head(15)
# Out:
# AgeDemographics
# <10       17
# 10-14     22
# 15-19    107
# 20-24    258
# 25-29     77
# 30-34     52
# 35-39     31
# 40+       12
# Name: SN, dtype: int64

# %%
GroupTotal = Groupbins.sum()
GroupTotal
# Out:
# 576

# %%
PercentPlay = (Groupbins / GroupTotal)*100
PercentPlay
# Out:
# AgeDemographics
# <10       2.951389
# 10-14     3.819444
# 15-19    18.576389
# 20-24    44.791667
# 25-29    13.368056
# 30-34     9.027778
# 35-39     5.381944
# 40+       2.083333
# Name: SN, dtype: float64

# %%
summary_table5 = pd.DataFrame({"Total Count": Groupbins, "Percentage of Players": PercentPlay})
summary_table5.head()
# Out:
#                  Total Count  Percentage of Players
# AgeDemographics
# <10                       17               2.951389
# 10-14                     22               3.819444
# 15-19                    107              18.576389
# 20-24                    258              44.791667
# 25-29                     77              13.368056

# %%
#THERE'S A DIFFERENCE IN THE README AND THE JUPYTER STARTER
#purchasing analysis
#The below each broken into bins of 4 years (i.e. &lt;10, 10-14, 15-19, etc.)
#Purchase Count
#Average Purchase Price
#Total Purchase Value
#Average Purchase Total per Person by Age Group
Groupbins2 = purchase_data.groupby("AgeDemographics")
Groupbins2.head(10)
# Out:
#      Purchase ID             SN  Age                 Gender  Item ID  \
# 0              0        Lisim78   20                   Male      108
# 1              1    Lisovynya38   40                   Male      143
# 2              2     Ithergue48   24                   Male       92
# 3              3  Chamassasya86   24                   Male      100
# 4              4      Iskosia90   23                   Male      131
# 5              5        Yalae81   22                   Male       81
# 6              6      Itheria73   36                   Male      169
# 7              7    Iskjaskst81   20                   Male      162
# 8              8      Undjask33   22                   Male       21
# 9              9    Chanosian48   35  Other / Non-Disclosed      136
# 10            10      Inguron55   23                   Male       95
# 11            11   Haisrisuir60   23                   Male      162
# 12            12   Saelaephos52   21                   Male      116
# ...

# %%
AvgPurPriceBin = Groupbins2["Price"].mean()
AvgPurPriceBin
# Out:
# AgeDemographics
# <10      3.353478
# 10-14    2.956429
# 15-19    3.035956
# 20-24    3.052219
# 25-29    2.900990
# 30-34    2.931507
# 35-39    3.601707
# 40+      2.941538
# Name: Price, dtype: float64

# %%
TotalPurBin = Groupbins2["Price"].sum()
TotalPurBin
# Out:
# AgeDemographics
# <10        77.13
# 10-14      82.78
# 15-19     412.89
# 20-24    1114.06
# 25-29     293.00
# 30-34     214.00
# 35-39     147.67
# 40+        38.24
# Name: Price, dtype: float64

# %%
#I still can't figure out how to get rid of doubles
AvgTotalBin = TotalPurBin / Groupbins
AvgTotalBin
# Out:
# AgeDemographics
# <10      4.537059
# 10-14    3.762727
# 15-19    3.858785
# 20-24    4.318062
# 25-29    3.805195
# 30-34    4.115385
# 35-39    4.763548
# 40+      3.186667
# dtype: float64

# %%
summary_table6 = pd.DataFrame({"Total Count": GroupCount, "Average Purchase Price": AvgPurPriceBin, "Total Purchase Value": TotalPurBin, "Avg Total Purchase Per Person": AvgTotalBin})
summary_table6
# Out:
#                  Total Count  Average Purchase Price  Total Purchase Value  \
# AgeDemographics
# <10                       23                3.353478                 77.13
# 10-14                     28                2.956429                 82.78
# 15-19                    136                3.035956                412.89
# 20-24                    365                3.052219               1114.06
# 25-29                    101                2.900990                293.00
# 30-34                     73                2.931507                214.00
# 35-39                     41                3.601707                147.67
# 40+                       13                2.941538                 38.24
#
#                  Avg Total Purchase Per Person
# AgeDemographics
# <10                                   4.537059
# 10-14                                 3.762727
# 15-19                                 3.858785
# 20-24                                 4.318062
# ...

# %%
summary_table6["Average Purchase Price"] = summary_table6["Average Purchase Price"].astype(float).map(
    "${:,.2f}".format)
summary_table6["Total Purchase Value"] = summary_table6["Total Purchase Value"].astype(float).map(
    "${:,.2f}".format)
#Once I get the number
summary_table6["Avg Total Purchase Per Person"] = summary_table6["Avg Total Purchase Per Person"].astype(float).map("${:,.2f}".format)
summary_table6
# Out:
#                  Total Count Average Purchase Price Total Purchase Value  \
# AgeDemographics
# <10                       23                  $3.35               $77.13
# 10-14                     28                  $2.96               $82.78
# 15-19                    136                  $3.04              $412.89
# 20-24                    365                  $3.05            $1,114.06
# 25-29                    101                  $2.90              $293.00
# 30-34                     73                  $2.93              $214.00
# 35-39                     41                  $3.60              $147.67
# 40+                       13                  $2.94               $38.24
#
#                 Avg Total Purchase Per Person
# AgeDemographics
# <10                                     $4.54
# 10-14                                   $3.76
# 15-19                                   $3.86
# 20-24                                   $4.32
# ...

# %%
reduced_purchase_data_df = purchase_data.loc[:, ["SN", "Price"]]
reduced_purchase_data_df.head()
# Out:
#               SN  Price
# 0        Lisim78   3.53
# 1    Lisovynya38   1.56
# 2     Ithergue48   4.88
# 3  Chamassasya86   3.27
# 4      Iskosia90   1.44

# %%
PurchaseCount = reduced_purchase_data_df["SN"].value_counts()
PurchaseCount
# Out:
# Lisosia93        5
# Idastidru52      4
# Iral74           4
# Yathecal82       3
# Lisopela58       3
# Hiaral50         3
# Raesty92         3
# Silaera56        3
# Phyali88         3
# Ilarin91         3
# Phaena87         3
# Rarallo90        3
# Lisim78          3
# Strithenu87      3
# Chanastnya43     3
# Saistyphos30     3
# Haillyrgue51     3
# Aelin32          3
# Iri67            3
# Saedaiphos46     3
# Ialallo29        3
# Chamjask73       3
# Chadolyla44      3
# Idai61           3
# Tyisur83         3
# Lassilsala30     3
# Zontibe81        3
# Hada39           3
# Aina42           3
# Inguron55        3
#                 ..
# Aeral97          1
# Philodil43       1
# Jeyciman68       1
# Meosridil82      1
# Chamimla73       1
# Lisosia66        1
# Ardonmol96       1
# Aina43           1
# Ililsasya43      1
# Risty84          1
# Lisista63        1
# Tyaenasti87      1
# Tyaedainu44      1
# Pheodai94        1
# Lisirra58        1
# Eulanurin88      1
# ...

# %%
# Create a GroupBy object based upon "SN"
GroupGroup = reduced_purchase_data_df.groupby("SN")
GroupGroup.head()
# Out:
#                   SN  Price
# 0            Lisim78   3.53
# 1        Lisovynya38   1.56
# 2         Ithergue48   4.88
# 3      Chamassasya86   3.27
# 4          Iskosia90   1.44
# 5            Yalae81   3.61
# 6          Itheria73   2.18
# 7        Iskjaskst81   2.67
# 8          Undjask33   1.10
# 9        Chanosian48   3.58
# 10         Inguron55   4.74
# 11      Haisrisuir60   2.67
# 12      Saelaephos52   4.18
# 13       Assjaskan73   1.70
# 14       Saesrideu94   4.86
# 15         Lisassa64   2.89
# 16         Lisirra25   2.52
# 17         Zontibe81   1.76
# 18         Reunasu60   4.90
# 19         Chamalo71   4.64
# 20      Iathenudil29   4.60
# 21     Phiarithdeu40   1.48
# 22      Siarithria38   3.81
# 23          Eyrian71   3.40
# 24           Siala43   3.19
# 25         Lisirra87   4.23
# 26        Lirtossa84   1.61
# 27           Eusri44   3.09
# 28            Aela59   4.32
# 29           Tyida79   3.16
# ..               ...    ...
# 750         Iljask75   3.61
# ...

# %%
# Get the average of each column within the GroupBy object
APP = GroupGroup[["Price"]].mean()
APP.head()
# Out:
#               Price
# SN
# Adairialis76   2.28
# Adastirin33    4.48
# Aeda94         4.91
# Aela59         4.32
# Aelaria33      1.79

# %%
#I can sum it too?
TPV = GroupGroup[["Price"]].sum()
TPV.head()
# Out:
#               Price
# SN
# Adairialis76   2.28
# Adastirin33    4.48
# Aeda94         4.91
# Aela59         4.32
# Aelaria33      1.79

# %%
#summary_table7 = pd.DataFrame({"Purchase Count": PurchaseCount, "Average Purchase Price": APP, "Total Purchase Value": TotalPurBin, "Avg Total Purchase Per Person": TPV})
#summary_table7

# %%
#popularitems
popular = purchase_data.loc[:, ["Item ID", "Item Name", "Price"]]
popular.head()
# Out:
#    Item ID                                  Item Name  Price
# 0      108  Extraction, Quickblade Of Trembling Hands   3.53
# 1      143                          Frenzied Scimitar   1.56
# 2       92                               Final Critic   4.88
# 3      100                                Blindscythe   3.27
# 4      131                                       Fury   1.44

# %%
PopularItem = popular.groupby("Item ID")["Item Name"]
PopularItem.head()
# Out:
# 0         Extraction, Quickblade Of Trembling Hands
# 1                                 Frenzied Scimitar
# 2                                      Final Critic
# 3                                       Blindscythe
# 4                                              Fury
# 5                                         Dreamkiss
# 6            Interrogator, Blood Blade of the Queen
# 7                                     Abyssal Shard
# 8                                         Souleater
# 9                      Ghastly Adamantite Protector
# 10                            Singed Onyx Warscythe
# 11                                    Abyssal Shard
# 12                          Renewed Skeletal Katana
# 13                               Bloodlord's Fetish
# 14                      Bone Crushing Silver Skewer
# 15                      Deadline, Voice Of Subtlety
# 16                                    Second Chance
# 17                                           Devine
# ...

# %%
PCount = popular["Item ID"].value_counts()
PCount.head()
# Out:
# 178    12
# 82      9
# 108     9
# 145     9
# 92      8
# Name: Item ID, dtype: int64

# %%
ItemPrice = popular["Price"]
ItemPrice.head()
# Out:
# 0    3.53
# 1    1.56
# 2    4.88
# 3    3.27
# 4    1.44
# Name: Price, dtype: float64

# %%
#TotPV = PCount * ItemPrice
#TotPV
#wrong, but trying to figure out
